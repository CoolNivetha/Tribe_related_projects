# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import openpyxl

import xlrd

# %%
Hourly_dist = pd.read_excel('./Touch_smily.xls', sheet_name = "Hourly distribution")

# %%
Hourly_dist
# Out:
#   Experience point / group                           Survey question  Date  \
# 0   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 1   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 2   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 3   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 4   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 5   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 6   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
# 7   Tampere - Smiley Touch  what was the reason of your visit today?   NaN
#
#    Year  Month  Week number  Day  Day of the week      Time Feedback scale  \
# 0   NaN    NaN          NaN  NaN              NaN  09:00:00      4 Smileys
# 1   NaN    NaN          NaN  NaN              NaN  10:00:00      4 Smileys
# ...
